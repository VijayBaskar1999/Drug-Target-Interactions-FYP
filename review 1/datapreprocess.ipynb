# %%
from rdkit import Chem

# %%
suppl = Chem.SDMolSupplier('../dataset/drug/structures.sdf')
mols = [x for x in suppl]
mols
# Out:
# ...
#  ...]

# %%
mols[0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-357e60aee869> in <module>
# ----> 1 mols[0].drugid
#
# AttributeError: 'Mol' object has no attribute 'drugid'
